# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.stats as sms
import numpy as np

# %%
data = pd.read_excel('for Sanya - monthly - cpi and exp cpi inflation.xlsx', index_col = 'Date')
data = data.loc['2003':]

# %%
tips_data = pd.read_csv('1. original_data/CPI/T10YIE.csv', index_col = 'DATE')
tips_data['T10YIE'] = tips_data['T10YIE'].replace('.', np.nan).astype(float) / 100
# tips_data = tips_data.diff(1).iloc[1:].dropna()
tips_data.index = pd.to_datetime(tips_data.index)

# %%
data = pd.concat([data, tips_data], axis = 1, join = 'inner').drop(['Month', 'Year'], axis = 1)
data = data.diff(1).iloc[1:]

# %%
import seaborn as sns

sns.pairplot(data)

# %%
y = data['T10YIE'].dropna()

x_names_list = data.columns.tolist()
x_names_list.remove('T10YIE')


models_list = []
for x_name in x_names_list:
    
    x = sm.add_constant(data[x_name].loc[y.index])
    
    model = sm.OLS(y, x).fit(cov_type = 'HC1')
    
    models_list.append(model)

# %%
for model in models_list:
    print(model.summary())
    print('\n\n\n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 T10YIE   R-squared:                       0.115
# Model:                            OLS   Adj. R-squared:                  0.110
# Method:                 Least Squares   F-statistic:                     12.90
# Date:                Sat, 11 May 2024   Prob (F-statistic):           0.000427
# Time:                        21:09:35   Log-Likelihood:                 846.79
# No. Observations:                 177   AIC:                            -1690.
# Df Residuals:                     175   BIC:                            -1683.
# Df Model:                           1
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        8.79e-05      0.000      0.585      0.559      -0.000       0.000
# CPI_Act        0.1064      0.030      3.592      0.000       0.048       0.164
# ==============================================================================
# Omnibus:                       49.709   Durbin-Watson:                   2.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              424.514
# Skew:                           0.713   Prob(JB):                     6.58e-93
# Kurtosis:                      10.452   Cond. No.                         146.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
#
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 T10YIE   R-squared:                       0.079
# Model:                            OLS   Adj. R-squared:                  0.074
# Method:                 Least Squares   F-statistic:                     6.172
# Date:                Sat, 11 May 2024   Prob (F-statistic):             0.0139
# Time:                        21:09:35   Log-Likelihood:                 843.28
# No. Observations:                 177   AIC:                            -1683.
# Df Residuals:                     175   BIC:                            -1676.
# Df Model:                           1
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8.991e-05      0.000      0.585      0.559      -0.000       0.000
# Exp_CPI_HH     0.1277      0.051      2.484      0.013       0.027       0.228
# ==============================================================================
# Omnibus:                       32.832   Durbin-Watson:                   2.058
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              223.948
# Skew:                           0.347   Prob(JB):                     2.35e-49
# Kurtosis:                       8.467   Cond. No.                         212.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
#
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 T10YIE   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.3341
# Date:                Sat, 11 May 2024   Prob (F-statistic):              0.564
# Time:                        21:09:35   Log-Likelihood:                 836.39
# No. Observations:                 177   AIC:                            -1669.
# Df Residuals:                     175   BIC:                            -1662.
# Df Model:                           1
# Covariance Type:                  HC1
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         6.639e-05      0.000      0.410      0.682      -0.000       0.000
# Exp_CPI_Clev     0.0299      0.052      0.578      0.563      -0.071       0.131
# ==============================================================================
# Omnibus:                       33.062   Durbin-Watson:                   2.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              292.533
# Skew:                           0.155   Prob(JB):                     3.00e-64
# Kurtosis:                       9.290   Cond. No.                         214.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
#
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 T10YIE   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     1.373
# Date:                Sat, 11 May 2024   Prob (F-statistic):              0.243
# Time:                        21:09:35   Log-Likelihood:                 837.81
# No. Observations:                 177   AIC:                            -1672.
# Df Residuals:                     175   BIC:                            -1665.
# Df Model:                           1
# Covariance Type:                  HC1
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          6.936e-05      0.000      0.434      0.664      -0.000       0.000
# Exp_CPI_ATSIX     0.2686      0.229      1.172      0.241      -0.181       0.718
# ==============================================================================
# Omnibus:                       36.013   Durbin-Watson:                   2.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              310.169
# Skew:                           0.320   Prob(JB):                     4.44e-68
# Kurtosis:                       9.453   Cond. No.                         883.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)

# %%
infl_type = 'Exp_CPI_Clev'
Y = data[infl_type].dropna()

x_names_list = data.columns.tolist()
x_names_list.remove(infl_type)


models_list = []
for x_name in x_names_list:
    
    x = sm.add_constant(data[x_name]).dropna()
    x = x.loc[[date for date in x.index if date in y.index]]
    
    y = Y.loc[x.index]
    
    model = sm.OLS(y, x).fit(cov_type = 'HC1')
    
    models_list.append(model)

# %%
for model in models_list:
    print(model.summary())
    print('\n\n\n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Exp_CPI_Clev   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     4.447
# Date:                Sat, 11 May 2024   Prob (F-statistic):             0.0363
# Time:                        21:14:08   Log-Likelihood:                 729.02
# No. Observations:                 183   AIC:                            -1454.
# Df Residuals:                     181   BIC:                            -1448.
# Df Model:                           1
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.522e-05      0.000      0.166      0.868      -0.001       0.001
# CPI_Act        0.1515      0.072      2.109      0.035       0.011       0.292
# ==============================================================================
# Omnibus:                        8.093   Durbin-Watson:                   2.637
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):               14.009
# Skew:                           0.141   Prob(JB):                     0.000908
# Kurtosis:                       4.326   Cond. No.                         146.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
#
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Exp_CPI_Clev   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     5.785
# Date:                Sat, 11 May 2024   Prob (F-statistic):             0.0172
# Time:                        21:14:08   Log-Likelihood:                 730.57
# No. Observations:                 183   AIC:                            -1457.
# Df Residuals:                     181   BIC:                            -1451.
# Df Model:                           1
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.784e-05      0.000      0.205      0.838      -0.001       0.001
# Exp_CPI_HH     0.2498      0.104      2.405      0.016       0.046       0.453
# ==============================================================================
# Omnibus:                        6.396   Durbin-Watson:                   2.569
# Prob(Omnibus):                  0.041   Jarque-Bera (JB):               10.362
# Skew:                          -0.042   Prob(JB):                      0.00562
# Kurtosis:                       4.163   Cond. No.                         210.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
#
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Exp_CPI_Clev   R-squared:                       0.077
# Model:                            OLS   Adj. R-squared:                  0.072
# Method:                 Least Squares   F-statistic:                     13.42
# Date:                Sat, 11 May 2024   Prob (F-statistic):           0.000327
# Time:                        21:14:08   Log-Likelihood:                 731.66
# No. Observations:                 183   AIC:                            -1459.
# Df Residuals:                     181   BIC:                            -1453.
# Df Model:                           1
# Covariance Type:                  HC1
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          2.148e-05      0.000      0.065      0.948      -0.001       0.001
# Exp_CPI_ATSIX     1.1345      0.310      3.663      0.000       0.528       1.742
# ==============================================================================
# Omnibus:                        9.051   Durbin-Watson:                   2.675
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):               17.558
# Skew:                           0.114   Prob(JB):                     0.000154
# Kurtosis:                       4.500   Cond. No.                         883.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
#
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Exp_CPI_Clev   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.3228
# Date:                Sat, 11 May 2024   Prob (F-statistic):              0.571
# Time:                        21:14:08   Log-Likelihood:                 698.78
# No. Observations:                 177   AIC:                            -1394.
# Df Residuals:                     175   BIC:                            -1387.
# Df Model:                           1
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -1.9e-05      0.000     -0.054      0.957      -0.001       0.001
# T10YIE         0.1414      0.249      0.568      0.570      -0.346       0.629
# ==============================================================================
# Omnibus:                        7.820   Durbin-Watson:                   2.590
# Prob(Omnibus):                  0.020   Jarque-Bera (JB):               13.817
# Skew:                          -0.109   Prob(JB):                     0.000999
# Kurtosis:                       4.351   Cond. No.                         465.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
